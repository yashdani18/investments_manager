# %%
import pandas as pd
from constants import KEYS_TICKER

# %%
df = pd.read_csv('data/raw.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#    Unnamed: 0                                   Name    Price  52 Week High  \
# 0           0  Computer Age Management Services Ltd.  2847.70        2988.0
# 1           1          Godawari Power And Ispat Ltd.   756.65         800.0
# 2           2       Happiest Minds Technologies Ltd.   934.90        1023.0
# 3           3                         HDFC Bank Ltd.  1679.15        1757.5
# 4           4               Kotak Mahindra Bank Ltd.  1848.00        2064.4
#
#    52 Week Low                 Sector      Ticker  \
# 0      2010.00               BPO/ITeS        CAMS
# 1       337.85  Steel & Iron Products        GPIL
# 2       763.25         IT - Software   HAPPSTMNDS
# 3      1460.25         Bank - Private    HDFCBANK
# 4      1643.50         Bank - Private   KOTAKBANK
#
#                     Finstar Rating Ownership Status  \
# 0  Valuation Rating is 4 out of 5.           Stable
# 1  Valuation Rating is 4 out of 5.           Stable
# ...
